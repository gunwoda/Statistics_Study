# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

loans_income = pd.read_csv("C:/Users/User/Documents/github/Statistics_Study/One/statistics data/data/loans_income.csv",squeeze=True)

sample_data = pd.DataFrame({
    'income' :  loans_income.sample(1000),
    'type': 'Data'
})
sample_mean_05 = pd.DataFrame({
    'income' : [loans_income.sample(5).mean() for _ in range(1000)],
    'type' : 'Mean of 5',
})
sample_mean_20 = pd.DataFrame({
    'income' : [loans_income.sample(20).mean() for _ in range(1000)],
    'type' : 'Mean of 20'
})
results = pd.concat([sample_data,sample_mean_05, sample_mean_20])

g = sns.FacetGrid(results, col = 'type', col_wrap = 1, height = 2, aspect = 2)
g.map(plt.hist, 'income', range=[0, 200000], bins =40)
g.set_axis_labels('Income', 'Count')
g.set_titles('{col_name}')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10356\401051312.py:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   loans_income = pd.read_csv("C:/Users/User/Documents/github/Statistics_Study/One/statistics data/data/loans_income.csv",squeeze=True)
